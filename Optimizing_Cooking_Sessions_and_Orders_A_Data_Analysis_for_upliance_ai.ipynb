# %% [markdown]
# <a href="https://colab.research.google.com/github/mansi-guptaa/Optimizing-Cooking-Sessions-and-Orders-A-Data-Analysis-for-upliance.ai/blob/main/Optimizing_Cooking_Sessions_and_Orders_A_Data_Analysis_for_upliance_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Optimizing Cooking Sessions and Orders: A Data Analysis for upliance.ai**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** - Mansi Gupta

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Objective:**
#
# This project aims to analyze data from upliance.ai, an AI-powered cooking assistant startup, to identify trends, patterns, and insights that can help optimize cooking sessions, order fulfillment, and overall business performance.
#
# **Data Source:**
#
# The analysis utilizes three datasets: UserDetails, CookingSessions, and OrderDetails. These datasets contain information about user demographics, cooking sessions, and order details, including meal types, dish preferences, order times, and user ratings.
#
# **Methodology:**
#
# The project follows a structured EDA approach:
#
# * Data Loading and Cleaning: Importing necessary libraries and loading datasets into Pandas DataFrames. Handling missing values and data cleaning are performed to ensure data quality.
# * Data Exploration and Visualization: Exploring variables, distributions, and relationships using descriptive statistics, visualizations, and data wrangling techniques.
# * Insight Generation: Deriving key insights and trends from the data analysis to understand user behavior, meal preferences, operational efficiency, and financial performance.
#
#
# **Key Findings:**
#
# * Dinner as a Key Driver: Dinner emerges as the most popular meal type, driving significant revenue and requiring optimized kitchen operations during evening hours.
# * Popular Dishes: Grilled Chicken and Spaghetti are identified as top choices among users, highlighting their importance in the menu.
# * High Session Ratings: The platform enjoys positive customer feedback, reflected in high session ratings, indicating customer satisfaction with the menu offerings.
# * Operational Efficiency: Session durations are generally efficient, with most sessions concentrated in the 30–40-minute range.
# * Low Cancellation Rates: A low cancellation rate suggests customer satisfaction with the platform's offerings, including accurate menu descriptions and pricing.
# * User Demographics: Most orders are from the 21-30 age group, indicating a key target audience.
#
# **Recommendations:**
#
# * Focus on dinner service and promotions to capitalize on its popularity and higher order values.
# * Improve user engagement and marketing efforts to address the decline in new user registrations.
# * Maintain operational efficiency by optimizing session durations for popular dishes without compromising customer satisfaction.
# * Continuously monitor customer feedback and ratings to identify areas for improvement and adapt strategies accordingly.
#
# **Conclusion:**
#
# This comprehensive analysis provides valuable insights into upliance.ai's operations and user behavior. By leveraging these insights and implementing the recommendations, upliance.ai can enhance customer satisfaction, optimize operations, and drive business growth

# %% [markdown]
# # **GitHub Link**

# %% [markdown]
# https://github.com/mansi-guptaa/Optimizing-Cooking-Sessions-and-Orders-A-Data-Analysis-for-upliance.ai

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **upliance.ai** has built India's first AI cooking assistant. Designed for beginners, the upliance simplifies and automates all parts of cooking for yourself. We're on a mission to push the boundaries of what home appliances can do for young India. As a disruptive startup, we take pride in our unique approach leveraging the power of AI to create hardware products that blend innovation with everyday utility. Directly collaborating closely with industry leaders like OpenAI and building fast.
#
# - The objective of this assignment is to analyze datasets related to user behavior, cooking preferences, and order trends.
# - You will work with three datasets: UserDetails, CookingSessions, and OrderDetails.
# - The task involves cleaning and merging the data, analyzing the relationship between cooking sessions and user orders, identifying popular dishes, and exploring demographic factors that influence user behavior.
# - Additionally, you will create visualizations to showcase key insights and write a report summarizing your findings and business recommendations.
# - The final project should be organized in a GitHub repository with all relevant files and a README.md.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
UserDetails_data = pd.read_excel("/content/Data Analyst Intern Assignment - Excel.xlsx", sheet_name = 'UserDetails.csv')
CookingSessions_data = pd.read_excel("/content/Data Analyst Intern Assignment - Excel.xlsx", sheet_name = 'CookingSessions.csv')
OrderDetails_data = pd.read_excel("/content/Data Analyst Intern Assignment - Excel.xlsx", sheet_name = 'OrderDetails.csv')

# %% [markdown]
# ### Dataset First View

# %%
# UserDetails_data First Look
UserDetails_data.head()
# Out:
#   User ID      User Name  Age       Location Registration Date         Phone  \
# 0    U001  Alice Johnson   28       New York        2023-01-15  123-456-7890
# 1    U002      Bob Smith   35    Los Angeles        2023-02-20  987-654-3210
# 2    U003    Charlie Lee   42        Chicago        2023-03-10  555-123-4567
# 3    U004    David Brown   27  San Francisco        2023-04-05  444-333-2222
# 4    U005     Emma White   30        Seattle        2023-05-22  777-888-9999
#
#                Email Favorite Meal  Total Orders
# 0    alice@email.com        Dinner            12
# 1      bob@email.com         Lunch             8
# 2  charlie@email.com     Breakfast            15
# 3    david@email.com        Dinner            10
# 4     emma@email.com         Lunch             9

# %%
# CookingSessions_data First Look
CookingSessions_data.head()
# Out:
#   Session ID User ID        Dish Name  Meal Type       Session Start  \
# 0       S001    U001        Spaghetti     Dinner 2024-12-01 19:00:00
# 1       S002    U002     Caesar Salad      Lunch 2024-12-01 12:00:00
# 2       S003    U003  Grilled Chicken     Dinner 2024-12-02 19:30:00
# 3       S004    U001         Pancakes  Breakfast 2024-12-02 07:30:00
# 4       S005    U004     Caesar Salad      Lunch 2024-12-03 13:00:00
#
#           Session End  Duration (mins)  Session Rating
# 0 2024-12-01 19:30:00               30             4.5
# 1 2024-12-01 12:20:00               20             4.0
# 2 2024-12-02 20:10:00               40             4.8
# 3 2024-12-02 08:00:00               30             4.2
# 4 2024-12-03 13:15:00               15             4.7

# %%
# OrderDetails_data First Look
OrderDetails_data.head()
# Out:
#    Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0      1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1      1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2      1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3      1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4      1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
#
#    Amount (USD) Time of Day  Rating Session ID
# 0          15.0       Night     5.0       S001
# 1          10.0         Day     4.0       S002
# 2          12.5       Night     NaN       S003
# 3           8.0     Morning     4.0       S004
# 4           9.0         Day     4.0       S005

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
UserDetails_data.shape
# Out:
# (10, 9)

# %%
# Dataset Rows & Columns count
CookingSessions_data.shape
# Out:
# (16, 8)

# %%
# Dataset Rows & Columns count
OrderDetails_data.shape
# Out:
# (16, 10)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
UserDetails_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            10 non-null     object
#  1   User Name          10 non-null     object
#  2   Age                10 non-null     int64
#  3   Location           10 non-null     object
#  4   Registration Date  10 non-null     datetime64[ns]
#  5   Phone              10 non-null     object
#  6   Email              10 non-null     object
#  7   Favorite Meal      10 non-null     object
#  8   Total Orders       10 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 848.0+ bytes

# %%
# Dataset Info
CookingSessions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Session ID       16 non-null     object
#  1   User ID          16 non-null     object
#  2   Dish Name        16 non-null     object
#  3   Meal Type        16 non-null     object
#  4   Session Start    16 non-null     datetime64[ns]
#  5   Session End      16 non-null     datetime64[ns]
#  6   Duration (mins)  16 non-null     int64
#  7   Session Rating   16 non-null     float64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
# Dataset Info
OrderDetails_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      16 non-null     int64
#  1   User ID       16 non-null     object
#  2   Order Date    16 non-null     datetime64[ns]
#  3   Meal Type     16 non-null     object
#  4   Dish Name     16 non-null     object
#  5   Order Status  16 non-null     object
#  6   Amount (USD)  16 non-null     float64
#  7   Time of Day   16 non-null     object
#  8   Rating        14 non-null     float64
#  9   Session ID    16 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 1.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
UserDetails_data.duplicated().sum()
# Out:
# 0

# %%
# Dataset Duplicate Value Count
CookingSessions_data.duplicated().sum()
# Out:
# 0

# %%
# Dataset Duplicate Value Count
OrderDetails_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
UserDetails_data.isnull().sum()
# Out:
# User ID              0
# User Name            0
# Age                  0
# Location             0
# Registration Date    0
# Phone                0
# Email                0
# Favorite Meal        0
# Total Orders         0
# dtype: int64

# %%
# Missing Values/Null Values Count
CookingSessions_data.isnull().sum()
# Out:
# Session ID         0
# User ID            0
# Dish Name          0
# Meal Type          0
# Session Start      0
# Session End        0
# Duration (mins)    0
# Session Rating     0
# dtype: int64

# %%
# Missing Values/Null Values Count
OrderDetails_data.isnull().sum()
# Out:
# Order ID        0
# User ID         0
# Order Date      0
# Meal Type       0
# Dish Name       0
# Order Status    0
# Amount (USD)    0
# Time of Day     0
# Rating          2
# Session ID      0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(data = UserDetails_data.isnull())
# Out:
# <Axes: >

# %%
# Visualizing the missing values
sns.heatmap(data = CookingSessions_data.isnull())
# Out:
# <Axes: >

# %%
# Visualizing the missing values
sns.heatmap(data = OrderDetails_data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Order detail dataset have null values while the other to dataset files are clean, they don't have null or duplicate values

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
UserDetails_data.columns
# Out:
# Index(['User ID', 'User Name', 'Age', 'Location', 'Registration Date', 'Phone',
#        'Email', 'Favorite Meal', 'Total Orders'],
#       dtype='object')

# %%
# Dataset Columns
CookingSessions_data.columns
# Out:
# Index(['Session ID', 'User ID', 'Dish Name', 'Meal Type', 'Session Start',
#        'Session End', 'Duration (mins)', 'Session Rating'],
#       dtype='object')

# %%
# Dataset Columns
OrderDetails_data.columns
# Out:
# Index(['Order ID', 'User ID', 'Order Date', 'Meal Type', 'Dish Name',
#        'Order Status', 'Amount (USD)', 'Time of Day', 'Rating', 'Session ID'],
#       dtype='object')

# %%
# Dataset Describe
UserDetails_data.describe()
# Out:
#              Age    Registration Date  Total Orders
# count  10.000000                   10     10.000000
# mean   31.800000  2023-05-27 02:24:00      9.400000
# min    25.000000  2023-01-15 00:00:00      5.000000
# 25%    28.250000  2023-03-16 12:00:00      7.250000
# 50%    30.500000  2023-06-03 00:00:00      8.500000
# 75%    34.500000  2023-08-01 00:00:00     11.500000
# max    42.000000  2023-10-10 00:00:00     15.000000
# std     5.266245                  NaN      3.339993

# %%
# Dataset Describe
CookingSessions_data.describe()
# Out:
#                     Session Start                    Session End  \
# count                          16                             16
# mean   2024-12-05 02:50:37.500000  2024-12-05 03:20:56.249999872
# min           2024-12-01 12:00:00            2024-12-01 12:20:00
# 25%           2024-12-03 08:37:30            2024-12-03 08:58:45
# 50%           2024-12-05 00:30:00            2024-12-05 00:57:30
# 75%           2024-12-06 23:22:30            2024-12-07 00:00:00
# max           2024-12-08 19:30:00            2024-12-08 20:10:00
# std                           NaN                            NaN
#
#        Duration (mins)  Session Rating
# count        16.000000       16.000000
# mean         30.312500        4.518750
# min          10.000000        4.000000
# 25%          20.000000        4.300000
# 50%          30.000000        4.550000
# 75%          40.000000        4.725000
# max          45.000000        5.000000
# std          10.873324        0.292617

# %%
# Dataset Describe
OrderDetails_data.describe()
# Out:
#           Order ID           Order Date  Amount (USD)     Rating
# count    16.000000                   16     16.000000  14.000000
# mean   1008.500000  2024-12-04 12:00:00     11.250000   4.285714
# min    1001.000000  2024-12-01 00:00:00      7.000000   4.000000
# 25%    1004.750000  2024-12-02 18:00:00      9.000000   4.000000
# 50%    1008.500000  2024-12-04 12:00:00     11.500000   4.000000
# 75%    1012.250000  2024-12-06 06:00:00     13.125000   4.750000
# max    1016.000000  2024-12-08 00:00:00     15.000000   5.000000
# std       4.760952                  NaN      2.435843   0.468807

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **UserDetails_data**
#
# Columns:
#
# * User ID: A unique identifier for each user.
# * User Name: Name of the user.
# * Age: User's age.
# * Location: The geographical location of the user.
# * Registration Date: Date when the user registered.
# * Phone: User's contact number.
# * Email: User's email address.
# * Favorite Meal: The user's preferred meal type.
# * Total Orders: The total number of orders placed by the user.
#
#
# **CookingSessions_data**
#
# Columns:
#
# * Session ID: Unique identifier for each cooking session.
# * User ID: Links the session to a specific user.
# * Dish Name: The dish being cooked during the session.
# * Meal Type: Type of meal (e.g., Breakfast, Lunch, Dinner).
# * Session Start: Start time of the cooking session.
# * Session End: End time of the cooking session.
# * Duration (mins): The total duration of the session in minutes.
# * Session Rating: Rating given for the cooking session.
#
# **OrderDetails_data**
#
# Columns:
#
# * Order ID: Unique identifier for each order.
# * User ID: Links the order to a specific user.
# * Order Date: The date the order was placed.
# * Meal Type: Type of meal ordered.
# * Dish Name: The dish ordered.
# * Order Status: Status of the order (e.g., Delivered, Pending).
# * Amount (USD): Total amount for the order.
# * Time of Day: The time when the order was placed.
# * Rating: Rating given for the order.
# * Session ID: Links the order to a specific cooking session, if applicable.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in UserDetails_data.columns:
  print("Number of unique values in", i ,"is :", UserDetails_data[i].nunique())
# Out:
# Number of unique values in User ID is : 10
# Number of unique values in User Name is : 10
# Number of unique values in Age is : 10
# Number of unique values in Location is : 10
# Number of unique values in Registration Date is : 10
# Number of unique values in Phone is : 10
# Number of unique values in Email is : 10
# Number of unique values in Favorite Meal is : 3
# Number of unique values in Total Orders is : 9

# %%
# Check Unique Values for each variable.
for i in CookingSessions_data.columns:
  print("Number of unique values in", i ,"is :", CookingSessions_data[i].nunique())
# Out:
# Number of unique values in Session ID is : 16
# Number of unique values in User ID is : 8
# Number of unique values in Dish Name is : 6
# Number of unique values in Meal Type is : 3
# Number of unique values in Session Start is : 16
# Number of unique values in Session End is : 16
# Number of unique values in Duration (mins) is : 6
# Number of unique values in Session Rating is : 11

# %%
# Check Unique Values for each variable.
for i in OrderDetails_data.columns:
  print("Number of unique values in", i ,"is :", OrderDetails_data[i].nunique())
# Out:
# Number of unique values in Order ID is : 16
# Number of unique values in User ID is : 8
# Number of unique values in Order Date is : 8
# Number of unique values in Meal Type is : 3
# Number of unique values in Dish Name is : 6
# Number of unique values in Order Status is : 2
# Number of unique values in Amount (USD) is : 12
# Number of unique values in Time of Day is : 3
# Number of unique values in Rating is : 2
# Number of unique values in Session ID is : 16

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Handling Null Values in OrderDetails_data
# It is observed that when the order status is cancelled there is no rating given so to impute null values in ratings  with 0 is reasonable

OrderDetails_data.fillna(0, inplace= True)
OrderDetails_data.isnull().sum()
# Out:
# Order ID        0
# User ID         0
# Order Date      0
# Meal Type       0
# Dish Name       0
# Order Status    0
# Amount (USD)    0
# Time of Day     0
# Rating          0
# Session ID      0
# dtype: int64

# %%
# Merge UserDetails_data with OrderDetails_data on 'User ID'
merged_df = pd.merge(OrderDetails_data, UserDetails_data, on='User ID', how='inner')

# Merge the result with CookingSessions_data on 'Session ID'
final_df = pd.merge(merged_df, CookingSessions_data, on='Session ID', how='inner')

final_df.head()
# Out:
#    Order ID User ID_x Order Date Meal Type_x      Dish Name_x Order Status  \
# 0      1001      U001 2024-12-01      Dinner        Spaghetti    Completed
# 1      1002      U002 2024-12-01       Lunch     Caesar Salad    Completed
# 2      1003      U003 2024-12-02      Dinner  Grilled Chicken     Canceled
# 3      1004      U001 2024-12-02   Breakfast         Pancakes    Completed
# 4      1005      U004 2024-12-03       Lunch     Caesar Salad    Completed
#
#    Amount (USD) Time of Day  Rating Session ID  ...              Email  \
# 0          15.0       Night     5.0       S001  ...    alice@email.com
# 1          10.0         Day     4.0       S002  ...      bob@email.com
# 2          12.5       Night     0.0       S003  ...  charlie@email.com
# 3           8.0     Morning     4.0       S004  ...    alice@email.com
# 4           9.0         Day     4.0       S005  ...    david@email.com
#
#    Favorite Meal Total Orders User ID_y      Dish Name_y Meal Type_y  \
# ...

# %%
# Dropping duplicate columns
final_df.drop(columns=['User ID_y', 'Dish Name_y', 'Meal Type_y'], inplace= True)  # Keep the '_x' columns and drop '_y'
# Rename columns to make them more consistent
final_df.rename(columns={'User ID_x': 'User ID', 'Meal Type_x': 'Meal Type', 'Dish Name_x': 'Dish Name'}, inplace = True)

# %%
final_df.head()
# Out:
#    Order ID User ID Order Date  Meal Type        Dish Name Order Status  \
# 0      1001    U001 2024-12-01     Dinner        Spaghetti    Completed
# 1      1002    U002 2024-12-01      Lunch     Caesar Salad    Completed
# 2      1003    U003 2024-12-02     Dinner  Grilled Chicken     Canceled
# 3      1004    U001 2024-12-02  Breakfast         Pancakes    Completed
# 4      1005    U004 2024-12-03      Lunch     Caesar Salad    Completed
#
#    Amount (USD) Time of Day  Rating Session ID  ...       Location  \
# 0          15.0       Night     5.0       S001  ...       New York
# 1          10.0         Day     4.0       S002  ...    Los Angeles
# 2          12.5       Night     0.0       S003  ...        Chicago
# 3           8.0     Morning     4.0       S004  ...       New York
# 4           9.0         Day     4.0       S005  ...  San Francisco
#
#    Registration Date         Phone              Email Favorite Meal  \
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### User Demographics

# %% [markdown]
# #### Chart - Total Orders by Age Group

# %%
# Chart - visualization code
# Creating age groups
final_df['Age Group'] = pd.cut(final_df['Age'], bins=[0, 20, 30, 40, 50, 100], labels=['0-20', '21-30', '31-40', '41-50', '51+'])

# Bar plot for Total Orders by Age Group
plt.figure(figsize=(8, 6))
sns.countplot(data=final_df, x='Age Group', palette='Set2')
plt.title('Total Orders by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Total Orders')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most orders are from the 21-30 age group during dinner hours, emphasizing the need for targeted campaigns."

# %% [markdown]
# #### Chart - Users Over Time (Registration)

# %%
# Chart - visualization code
plt.figure(figsize=(10, 6))
final_df['Registration Date'].value_counts().sort_index().plot(kind='line', marker='o', color='purple')
plt.title('Users Over Time (Registration)')
plt.xlabel('Registration Date')
plt.ylabel('Number of Users')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The new users over time decreases which indicated the need to enlarging the customer base and promoting effective marketing

# %% [markdown]
# #### Chart - Top 5 Users by Total Spending

# %%
# Grouping by User ID to calculate metrics
top_users = final_df.groupby('User Name').agg(
    Total_Orders=('Order ID', 'count'),
    Total_Spent=('Amount (USD)', 'sum')
).reset_index()

# Sorting users by Total Spent
top_users = top_users.sort_values(by='Total_Spent', ascending=False).head(5)  # Top 10 users

# Plotting the bar chart for Total Spent
plt.figure(figsize=(8, 6))
sns.barplot(x='User Name', y='Total_Spent', data=top_users, palette='Set2')
plt.title('Top 5 Users by Total Spending')
plt.xlabel('User Name')
plt.ylabel('Total Amount Spent (USD)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The new users over time decreases which indicated the need to enlarging the customer base and promoting effective marketing

# %% [markdown]
# ### Order Trends

# %% [markdown]
# #### Chart - Order Count by Time of Day

# %%
# Chart - visualization code
# Count plot for Time of Day
plt.figure(figsize=(8, 6))
sns.countplot(data=final_df, x='Time of Day', palette='Set2')
plt.title('Order Count by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Order Count')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Orders peak in the night, requiring optimized kitchen operations during these hours.

# %% [markdown]
# #### Chart  - User Orders Over Time

# %%
# visualization code

# Group by Order Date and count orders
orders_over_time = final_df.groupby('Order Date').size()

# Line plot for Orders over Time
plt.figure(figsize=(10, 6))
orders_over_time.plot(kind='line', color='orange')
plt.title('User Orders Over Time')
plt.xlabel('Order Date')
plt.ylabel('Order Count')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Users order over time are steady which is a good sign but it also leaves room for improving the order count rather then keeping it steady.

# %% [markdown]
# #### Chart - Order Distribution by location

# %%
# Chart - visualization code

plt.figure(figsize=(10, 6))
final_df.groupby('Location')['Order ID'].count().plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Order Distribution')
plt.ylabel('')  # Remove y-axis label for a cleaner pie chart
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Major customer base are in Los Angeles, chicago, NewYork and Bosten , Austin and Miami can be potiential customer base.

# %% [markdown]
# ###  Meal Preferences

# %% [markdown]
# #### Chart - Order Count by Meal Type

# %%
# Chart -  visualization code

# Count plot for Meal Type
plt.figure(figsize=(8, 6))
sns.countplot(data=final_df, x='Meal Type', palette='Set2', hue = "Meal Type")
plt.title('Order Count by Meal Type')
plt.xlabel('Meal Type')
plt.ylabel('Order Count')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Meal Type Analysis revealed Dinner as the most popular option, contributing to 60% of total orders. This insight suggests allocating more resources to evening operations and targeting promotions for dinner menus.

# %% [markdown]
# #### Chart - Top Dish

# %%
# visualization code
# Count the favorite meals
top_meals = final_df['Dish Name'].value_counts()

# Bar plot for Top 10 Favorite Meals
plt.figure(figsize=(10, 6))
top_meals.plot(kind='barh', color = 'orange')
plt.title('Top Dish')
plt.xlabel('Order Count')
plt.ylabel('Dish Name')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Grilled Chicken and Spaghetti is the most popular dish with a high session rating, highlighting its importance in the menu.

# %% [markdown]
# #### Chart - Top Favorite Meals

# %%
# visualization code

# Count the favorite meals
top_meals = final_df['Favorite Meal'].value_counts()

# Bar plot for Top 10 Favorite Meals
plt.figure(figsize=(10, 6))
top_meals.plot(kind='barh', color='orange')
plt.title('Top Favorite Meals')
plt.xlabel('Order Count')
plt.ylabel('Favorite Meal')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The preference for meal is dinner , people prefer dinner the most as compared to breakfast , which suggest for targeted strategies for the dinner menu like improving , enhancing  and adding new items in the dinner menu.

# %% [markdown]
# ###  Financial Insights

# %% [markdown]
# #### Chart - Amount by Meal Type

# %%
# Chart - visualization code

plt.figure(figsize=(10, 6))
sns.barplot(x='Meal Type', y='Amount (USD)', data=final_df, ci=None, palette='Set2')
plt.title('Amount by Meal Type')
plt.xlabel('Meal Type')
plt.ylabel('Amount (USD)')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Dinner orders are a key revenue driver, given their higher frequency and value. It highlights the importance of focusing on dinner offerings to maximize profitability.

# %% [markdown]
# #### Chart  - Distribution of Order Amount (USD)

# %%
# Chart -  visualization code
# Histogram of Amount (USD)
plt.figure(figsize=(8, 6))
sns.histplot(final_df['Amount (USD)'], kde=True, color='blue')
plt.title('Distribution of Order Amount (USD)')
plt.xlabel('Amount (USD)')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Since most of the orders are for dinner and they poses higher order value so most of the orders are of 12 - 15 USD

# %% [markdown]
# ### User Feedback

# %% [markdown]
# #### Chart - Session Duration vs. Session Rating

# %%
# Chart -  visualization code
# Scatter plot for Session Duration vs. Session Rating
plt.figure(figsize=(8, 6))
sns.scatterplot(data=final_df, x='Duration (mins)', y='Session Rating',hue='Meal Type', palette='Set1')
plt.title('Session Duration vs. Session Rating')
plt.xlabel('Session Duration (mins)')
plt.ylabel('Session Rating')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no liner relationship between the variable but it highlights average duration is 30 mins and dinner gets the highest ratings and they take more time to be prepared.

# %% [markdown]
# #### Chart  - Average Session Rating by Dish Name

# %%
# Chart -  visualization code
# Bar plot for Average Rating by Dish Name
average_rating = final_df.groupby('Dish Name')['Session Rating'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
average_rating.plot(kind='bar', color='skyblue')
plt.title('Average Session Rating by Dish Name')
plt.xlabel('Dish Name')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most highest rated dish is Grilled chicken which is the top dish of the menu

# %% [markdown]
# ### Operational Efficiency

# %% [markdown]
# #### Chart - Session Duration Distribution

# %%
#  visualization code

plt.figure(figsize=(10, 6))
sns.histplot(final_df["Duration (mins)"], kde=True, bins=10, color='blue')
plt.title("Session Duration Distribution")
plt.xlabel("Session Duration (mins)")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution of session durations appears to be somewhat right-skewed, with more sessions concentrated in the 30–40-minute range.

# %% [markdown]
# #### Chart - Average Session Duration by Dish Name

# %%
#  visualization code

plt.figure(figsize=(14, 6))
dish_duration = final_df.groupby('Dish Name')['Duration (mins)'].mean().reset_index()
sns.barplot(data=dish_duration, x='Duration (mins)', y='Dish Name', palette='Set2')
plt.title('Average Session Duration by Dish Name', fontsize=16)
plt.xlabel('Average Duration (mins)', fontsize=12)
plt.ylabel('Dish Name', fontsize=12)
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Highest rated dish ie Grilled chicken has the highest session time while Oatmeal has the lowest.

# %% [markdown]
# #### Chart - Session Rating Distribution

# %%
# Chart - 13 visualization code
plt.figure(figsize=(10, 6))
sns.histplot(final_df['Session Rating'], kde=True, bins=5, color='blue', edgecolor='black')
plt.title('Session Rating Distribution')
plt.xlabel('Session Rating')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the dishes are rated highest which means the menu offerings align well with customer preferences and expectations, leading to positive feedback.

# %% [markdown]
# #### Chart - Order Amount vs. Rating

# %%
# Chart - visualization code
# Scatter plot for Amount (USD) vs. Rating
plt.figure(figsize=(8, 6))
sns.scatterplot(data=final_df, x='Amount (USD)', y='Rating', hue='Meal Type', palette='Set1')
plt.title('Order Amount vs. Rating')
plt.xlabel('Amount (USD)')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no significant relationship between the rating and amount. Most of the dishes get 4 above rating.

# %% [markdown]
# ### Order Status Analysis

# %% [markdown]
# #### Chart - Order Distribution

# %%
# Chart - visualization code
plt.figure(figsize=(10, 6))
final_df['Order Status'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Order Distribution')
plt.ylabel('')  # Remove y-axis label for a cleaner pie chart
plt.show()

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the orders are completed rather than being cancelled. A low cancellation rate indicates that customers are satisfied with the platform's offerings, such as accurate menu descriptions, pricing, and availability.

# %% [markdown]
# ### Relationships and Correlations

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(10,8))
numeric_df = final_df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(),annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Duration (mins) and Amount (USD) have a high positive correlation (0.65). This suggests that longer session durations are associated with higher amounts spent.
# Duration (mins) and Session Rating have a strong positive correlation (0.69), indicating that longer sessions tend to have better session ratings.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(final_df)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The realtionship between the variables are non linear in nature.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# * **Focus on Dinner Service**: As dinner is the most popular meal type with higher order values, allocate more resources to optimize dinner operations, including kitchen staffing and delivery efficiency. Consider introducing new and enticing dinner menu options to further boost sales.
#
# * **Targeted Promotions:** Implement targeted promotions for dinner and the most popular dishes, such as Grilled Chicken and Spaghetti. This can include discounts, combo offers, or loyalty programs to encourage repeat purchases and attract new customers.
#
# * **Improve User Engagement:** Address the decline in new user registrations by enhancing marketing efforts and exploring new channels to reach a wider audience. Consider introducing referral programs, social media campaigns, or partnerships to increase brand visibility and attract new users.
#
# * **Maintain Operational Efficiency:** While maintaining high session ratings, explore ways to optimize session durations for popular dishes without compromising customer satisfaction. This could involve streamlining preparation processes or offering pre-ordering options to reduce wait times.
#
# * **Continue Monitoring Feedback:** Continuously monitor customer feedback and ratings to identify areas for improvement and address any emerging issues promptly. This can include regular surveys, feedback forms, or social media monitoring to gather insights and adapt strategies accordingly.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This comprehensive analysis of the dataset has provided valuable insights into user behavior, order trends, and operational efficiency. By leveraging these insights, upliance can implement targeted strategies to enhance customer satisfaction, optimize operations, and ultimately drive business growth.
#
# Key Findings:
#
# * Dinner Dominance: Dinner emerged as the most popular meal type, driving significant revenue.
# * Popular Dishes: Grilled Chicken and Spaghetti were identified as top choices among users, highlighting their importance in the menu.
# * High Session Ratings: The platform enjoys positive customer feedback, reflected in high session ratings.
# * Operational Efficiency: Session durations are generally efficient, with most sessions concentrated in the 30–40-minute range.
# * Low Cancellation Rates: A low cancellation rate suggests customer satisfaction with the platform's offerings.

# %% [markdown]
# ### ***Hope you like the analysis. Open for suggestion and Feedback. Thanks for your time!!!***
